# %%
import pandas as pd
import numpy as np

# %%
class Perceptron:
    
    def __init__(self):
      self.weight=None
    # Find the classification for the feature vector
    # Found according to the current weight vector

    def weight(self):
      return self.weight
    # Train the weight vector according to the feature vectors and their
    # corresponding classification
    def fit(self, X, y):
      # Add a bias column of all 1s
      X["bias"] = 1
      self.weight = np.zeros(X.shape[1])
      misclassifications = 0
      count = 0
      while True:
        count += 1
        misclassifications = 0
        for i in range(X.shape[0]):
          X_i = X.iloc[i, :]
          Y_i = y.iloc[i]
          if Y_i*np.dot(self.weight, X_i) <= 0 :
            self.weight = self.weight + X_i*Y_i
            misclassifications += 1
        if count%5 == 0:
          print(self.weight)
          print("Misclassified:\t"+
                str(misclassifications) + "\tCount:\t"+ str(count))
        # Break while loop when all data is classified correctly
        if misclassifications == 0:
          break
      return
    # Return a row containing classification for each row in X
    # Found according to our weight vector
    def predict(self, X):
      prediction = []
      # Add a bias column of all 1s
      X["bias"] = 1
      for i in range(X.shape[0]):
        X_i = X.iloc[i, :]
        if np.dot(self.weight, X_i) > 0:
          prediction.append(1)
        else:
          prediction.append(-1)
      return prediction

# %%
df = pd.read_csv("data.csv")
df = df.dropna()
tr = df.iloc[:375,:]
test = df.iloc[375:, :]
y = tr.iloc[:, 1]

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 370    M
# 371    B
# 372    M
# 373    M
# 374    B
# Name: diagnosis, Length: 375, dtype: object

# %%
tr = tr.drop(tr.columns[[0,1]], axis=1)
test = test.drop(test.columns[[0,1]], axis=1)

# %%
y.replace('M', 1, inplace = True)
y.replace('B', -1, inplace = True)

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 370    1
# 371   -1
# 372    1
# 373    1
# 374   -1
# Name: diagnosis, Length: 375, dtype: int64

# %%
test
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 375        16.17         16.07          106.30      788.5          0.09880
# 376        10.57         20.22           70.15      338.3          0.09073
# 377        13.46         28.21           85.89      562.1          0.07517
# 378        13.66         15.15           88.27      580.6          0.08268
# 379        11.08         18.83           73.30      361.6          0.12160
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 375           0.14380         0.06651              0.05397         0.1990
# 376           0.16600         0.22800              0.05941         0.2188
# 377           0.04726         0.01271              0.01117         0.1421
# 378           0.07548         0.04249              0.02471         0.1792
# 379           0.21540         0.16890              0.06367         0.2196
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 375                 0.06572  ...        16.970          19.14
# 376                 0.08450  ...        10.850          22.82
# 377                 0.05763  ...        14.690          35.63
# 378                 0.05897  ...        14.540          19.64
# 379                 0.07950  ...        13.240          32.82
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 375           113.10       861.5           0.12350            0.25500
# 376            76.51       351.9           0.11430            0.36190
# 377            97.11       680.6           0.11080            0.14570
# 378            97.96       657.0           0.12750            0.31040
# 379            91.76       508.1           0.21840            0.93790
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 375          0.21140               0.12510          0.3153
# 376          0.60300               0.14650          0.2597
# 377          0.07934               0.05781          0.2694
# 378          0.25690               0.10540          0.3387
# 379          0.84020               0.25240          0.4154
# ..               ...                   ...             ...
# 564          0.41070               0.22160          0.2060
# 565          0.32150               0.16280          0.2572
# 566          0.34030               0.14180          0.2218
# 567          0.93870               0.26500          0.4087
# 568          0.00000               0.00000          0.2871
#
#      fractal_dimension_worst
# 375                  0.08960
# 376                  0.12000
# 377                  0.07061
# 378                  0.09638
# 379                  0.14030
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [188 rows x 30 columns]

# %%
tr
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 370        16.35         23.29          109.00      840.4          0.09742
# 371        15.19         13.21           97.65      711.8          0.07963
# 372        21.37         15.10          141.30     1386.0          0.10010
# 373        20.64         17.35          134.80     1335.0          0.09446
# 374        13.69         16.07           87.84      579.1          0.08302
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 370           0.14970         0.18110              0.08773         0.2175
# 371           0.06934         0.03393              0.02657         0.1721
# 372           0.15150         0.19320              0.12550         0.1973
# 373           0.10760         0.15270              0.08941         0.1571
# 374           0.06374         0.02556              0.02031         0.1872
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                   0.07871  ...         25.38          17.33
# 1                   0.05667  ...         24.99          23.41
# 2                   0.05999  ...         23.57          25.53
# 3                   0.09744  ...         14.91          26.50
# 4                   0.05883  ...         22.54          16.67
# ..                      ...  ...           ...            ...
# 370                 0.06218  ...         19.38          31.03
# 371                 0.05544  ...         16.20          15.73
# 372                 0.06183  ...         22.69          21.84
# 373                 0.05478  ...         25.37          23.17
# 374                 0.05669  ...         14.84          20.21
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0             184.60      2019.0            0.1622             0.6656
# 1             158.80      1956.0            0.1238             0.1866
# 2             152.50      1709.0            0.1444             0.4245
# 3              98.87       567.7            0.2098             0.8663
# 4             152.20      1575.0            0.1374             0.2050
# ..               ...         ...               ...                ...
# 370           129.30      1165.0            0.1415             0.4665
# 371           104.50       819.1            0.1126             0.1737
# 372           152.10      1535.0            0.1192             0.2840
# 373           166.80      1946.0            0.1562             0.3055
# 374            99.16       670.6            0.1105             0.2096
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.7119               0.26540          0.4601
# 1             0.2416               0.18600          0.2750
# 2             0.4504               0.24300          0.3613
# 3             0.6869               0.25750          0.6638
# 4             0.4000               0.16250          0.2364
# ..               ...                   ...             ...
# 370           0.7087               0.22480          0.4824
# 371           0.1362               0.08178          0.2487
# 372           0.4024               0.19660          0.2730
# 373           0.4159               0.21120          0.2689
# 374           0.1346               0.06987          0.3323
#
#      fractal_dimension_worst
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 370                  0.09614
# 371                  0.06766
# 372                  0.08666
# 373                  0.07055
# 374                  0.07701
#
# [375 rows x 30 columns]

# %%
model = Perceptron()
model.fit(tr, y)
predicted = model.predict(test)
# Out:
# Streaming output truncated to the last 5000 lines.
# concavity_se                17305.787710
# concave points_se            3903.625538
# symmetry_se                  7876.094609
# fractal_dimension_se          972.677349
# radius_worst              -339922.110002
# texture_worst               29951.440000
# perimeter_worst            103616.750000
# area_worst                   4595.100000
# smoothness_worst            26161.878400
# compactness_worst          159812.612158
# concavity_worst            214701.959227
# concave points_worst        60574.551674
# symmetry_worst              67715.436100
# fractal_dimension_worst     19679.164390
# bias                       -38950.000000
# dtype: float64
# Misclassified:	24	Count:	81860
# radius_mean               -337464.522002
# texture_mean                73500.770000
# perimeter_mean            -129687.550000
# area_mean                    7138.100000
# smoothness_mean             17301.922620
# compactness_mean            59828.955050
# concavity_mean              85721.628697
# concave points_mean         38202.863655
# symmetry_mean               21429.123100
# fractal_dimension_mean       6759.253740
# radius_se                   -7786.767700
# texture_se                 -55959.906600
# perimeter_se               -85779.140399
# area_se                     20455.492000
# smoothness_se                1887.063129
# compactness_se              10596.310956
# concavity_se                17306.732130
# concave points_se            3903.894049
# symmetry_se                  7876.546882
# fractal_dimension_se          972.743953
# radius_worst              -339912.280002
# texture_worst               29983.840000
# perimeter_worst            103775.540000
# area_worst                   6070.900000
# smoothness_worst            26163.443020
# compactness_worst          159819.654758
# concavity_worst            214711.688237
# concave points_worst        60577.853714
# symmetry_worst              67719.515200
# fractal_dimension_worst     19680.270980
# bias                       -38950.000000
# dtype: float64
# Misclassified:	26	Count:	81865
# radius_mean               -337493.332002
# texture_mean                73494.310000
# perimeter_mean            -129789.380000
# area_mean                    6487.500000
# smoothness_mean             17302.678560
# compactness_mean            59831.272730
# concavity_mean              85725.167717
# concave points_mean         38204.588445
# symmetry_mean               21430.037600
# fractal_dimension_mean       6759.537440
# radius_se                   -7787.237800
# texture_se                 -55963.669900
# perimeter_se               -85785.879399
# area_se                     20422.802000
# smoothness_se                1887.199589
# compactness_se              10596.653896
# concavity_se                17307.515310
# concave points_se            3904.125934
# symmetry_se                  7876.896366
# fractal_dimension_se          972.790637
# radius_worst              -339941.840002
# texture_worst               29969.790000
# perimeter_worst            103659.600000
# area_worst                   5198.200000
# smoothness_worst            26164.610340
# compactness_worst          159825.080258
# concavity_worst            214719.569947
# concave points_worst        60580.547064
# symmetry_worst              67722.447800
# fractal_dimension_worst     19681.042080
# bias                       -38952.000000
# dtype: float64
# Misclassified:	18	Count:	81870
# radius_mean               -337500.452002
# texture_mean                73500.700000
# perimeter_mean            -129737.110000
# area_mean                    7263.200000
# smoothness_mean             17303.621960
# compactness_mean            59834.119510
# concavity_mean              85729.437307
# concave points_mean         38206.655765
# symmetry_mean               21431.332100
# fractal_dimension_mean       6759.941210
# radius_se                   -7787.116300
# texture_se                 -55965.673000
# perimeter_se               -85787.260399
# area_se                     20443.022000
# smoothness_se                1887.347173
# compactness_se              10597.144476
# concavity_se                17308.469810
# concave points_se            3904.396689
# symmetry_se                  7877.331379
# fractal_dimension_se          972.855749
# radius_worst              -339946.480002
# texture_worst               29977.370000
# perimeter_worst            103724.790000
# area_worst                   5995.800000
# smoothness_worst            26166.020460
# compactness_worst          159831.897458
# concavity_worst            214729.137867
# concave points_worst        60583.819744
# symmetry_worst              67726.247800
# fractal_dimension_worst     19682.060670
# bias                       -38953.000000
# dtype: float64
# Misclassified:	21	Count:	81875
# radius_mean               -337516.342002
# texture_mean                73509.160000
# perimeter_mean            -129746.010000
# area_mean                    7129.700000
# smoothness_mean             17304.568750
# compactness_mean            59836.901890
# concavity_mean              85733.580457
# concave points_mean         38208.637705
# symmetry_mean               21432.644500
# fractal_dimension_mean       6760.349350
# radius_se                   -7787.653400
# texture_se                 -55968.500000
# perimeter_se               -85791.608399
# area_se                     20396.482000
# smoothness_se                1887.493357
# compactness_se              10597.560366
# concavity_se                17309.351500
# concave points_se            3904.648907
# symmetry_se                  7877.742522
# fractal_dimension_se          972.902315
# radius_worst              -339957.120002
# texture_worst               29999.790000
# perimeter_worst            103748.680000
# area_worst                   6115.900000
# smoothness_worst            26167.493500
# compactness_worst          159839.092258
# concavity_worst            214738.979287
# concave points_worst        60587.117624
# symmetry_worst              67730.266200
# fractal_dimension_worst     19683.129900
# bias                       -38954.000000
# dtype: float64
# Misclassified:	23	Count:	81880
# radius_mean               -337512.602002
# texture_mean                73560.220000
# perimeter_mean            -129619.180000
# area_mean                    6595.200000
# smoothness_mean             17305.987770
# compactness_mean            59840.423010
# concavity_mean              85738.164887
# concave points_mean         38210.787855
# symmetry_mean               21434.617900
# fractal_dimension_mean       6761.039240
# radius_se                   -7786.889500
# texture_se                 -55970.073900
# perimeter_se               -85790.636399
# area_se                     20405.302000
# smoothness_se                1887.625319
# compactness_se              10598.086696
# concavity_se                17310.229460
# concave points_se            3904.892738
# symmetry_se                  7878.233714
# fractal_dimension_se          972.970649
# radius_worst              -339937.870002
# texture_worst               30075.650000
# perimeter_worst            103974.100000
# area_worst                   6487.000000
# smoothness_worst            26169.702470
# compactness_worst          159848.316558
# concavity_worst            214750.705207
# concave points_worst        60590.864604
# symmetry_worst              67735.374200
# fractal_dimension_worst     19684.658020
# bias                       -38952.000000
# dtype: float64
# Misclassified:	26	Count:	81885
# radius_mean               -337550.992002
# texture_mean                73537.550000
# perimeter_mean            -129784.880000
# area_mean                    6571.300000
# smoothness_mean             17306.423120
# compactness_mean            59842.251010
# concavity_mean              85741.347987
# concave points_mean         38212.366415
# symmetry_mean               21434.950500
# fractal_dimension_mean       6761.110920
# radius_se                   -7787.272400
# texture_se                 -55973.726300
# perimeter_se               -85798.623399
# area_se                     20417.132000
# smoothness_se                1887.774094
# compactness_se              10598.439976
# concavity_se                17311.063690
# concave points_se            3905.140583
# symmetry_se                  7878.542569
# fractal_dimension_se          973.025623
# radius_worst              -339990.890002
# texture_worst               30014.310000
# perimeter_worst            103703.290000
# area_worst                   5084.400000
# smoothness_worst            26170.344970
# compactness_worst          159851.616858
# concavity_worst            214756.371407
# concave points_worst        60592.979514
# symmetry_worst              67736.860600
# fractal_dimension_worst     19684.982730
# bias                       -38956.000000
# dtype: float64
# Misclassified:	18	Count:	81890
# radius_mean               -337559.112002
# texture_mean                73535.720000
# perimeter_mean            -129739.410000
# area_mean                    7251.000000
# smoothness_mean             17307.393910
# compactness_mean            59845.097690
# concavity_mean              85745.641477
# concave points_mean         38214.454775
# symmetry_mean               21436.262200
# fractal_dimension_mean       6761.522150
# radius_se                   -7787.033700
# texture_se                 -55976.355100
# perimeter_se               -85799.681399
# area_se                     20450.402000
# smoothness_se                1887.920444
# compactness_se              10598.912826
# concavity_se                17312.007510
# concave points_se            3905.406408
# symmetry_se                  7878.978682
# fractal_dimension_se          973.090319
# radius_worst              -339994.530002
# texture_worst               30010.480000
# perimeter_worst            103769.980000
# area_worst                   6002.800000
# smoothness_worst            26171.766690
# compactness_worst          159858.325658
# concavity_worst            214765.936127
# concave points_worst        60596.231394
# symmetry_worst              67740.676800
# fractal_dimension_worst     19686.007130
# bias                       -38957.000000
# dtype: float64
# Misclassified:	21	Count:	81895
# radius_mean               -337581.092002
# texture_mean                73534.600000
# perimeter_mean            -129798.890000
# area_mean                    6498.400000
# smoothness_mean             17308.275470
# compactness_mean            59847.518380
# concavity_mean              85749.049067
# concave points_mean         38216.155925
# symmetry_mean               21437.335600
# fractal_dimension_mean       6761.878130
# radius_se                   -7786.924300
# texture_se                 -55980.132900
# perimeter_se               -85804.331399
# area_se                     20443.402000
# smoothness_se                1888.039553
# compactness_se              10599.261036
# concavity_se                17312.715540
# concave points_se            3905.626104
# symmetry_se                  7879.333126
# fractal_dimension_se          973.147009
# radius_worst              -340015.290002
# texture_worst               29994.950000
# perimeter_worst            103708.880000
# area_worst                   5150.500000
# smoothness_worst            26173.107040
# compactness_worst          159863.756958
# concavity_worst            214773.621337
# concave points_worst        60598.893354
# symmetry_worst              67743.711300
# fractal_dimension_worst     19686.853870
# bias                       -38958.000000
# dtype: float64
# Misclassified:	18	Count:	81900
# radius_mean               -337589.212002
# texture_mean                73532.770000
# perimeter_mean            -129753.420000
# area_mean                    7178.100000
# smoothness_mean             17309.246260
# compactness_mean            59850.365060
# concavity_mean              85753.342557
# concave points_mean         38218.244285
# symmetry_mean               21438.647300
# fractal_dimension_mean       6762.289360
# radius_se                   -7786.685600
# texture_se                 -55982.761700
# perimeter_se               -85805.389399
# area_se                     20476.672000
# smoothness_se                1888.185903
# compactness_se              10599.733886
# concavity_se                17313.659360
# concave points_se            3905.891929
# symmetry_se                  7879.769239
# fractal_dimension_se          973.211705
# radius_worst              -340018.930002
# texture_worst               29991.120000
# perimeter_worst            103775.570000
# area_worst                   6068.900000
# smoothness_worst            26174.528760
# compactness_worst          159870.465758
# concavity_worst            214783.186057
# concave points_worst        60602.145234
# symmetry_worst              67747.527500
# fractal_dimension_worst     19687.878270
# bias                       -38959.000000
# dtype: float64
# Misclassified:	23	Count:	81905
# radius_mean               -337598.272002
# texture_mean                73546.570000
# perimeter_mean            -129719.970000
# area_mean                    6942.600000
# smoothness_mean             17310.318670
# compactness_mean            59853.250450
# concavity_mean              85757.354277
# concave points_mean         38220.202585
# symmetry_mean               21440.118600
# fractal_dimension_mean       6762.769780
# radius_se                   -7786.643200
# texture_se                 -55985.603200
# perimeter_se               -85807.648399
# area_se                     20455.822000
# smoothness_se                1888.314736
# compactness_se              10600.155046
# concavity_se                17314.465900
# concave points_se            3906.131958
# symmetry_se                  7880.185342
# fractal_dimension_se          973.268277
# radius_worst              -340020.770002
# texture_worst               30012.060000
# perimeter_worst            103854.300000
# area_worst                   6209.400000
# smoothness_worst            26176.174830
# compactness_worst          159877.666358
# concavity_worst            214792.830977
# concave points_worst        60605.411724
# symmetry_worst              67751.647800
# fractal_dimension_worst     19689.023140
# bias                       -38959.000000
# dtype: float64
# Misclassified:	26	Count:	81910
# radius_mean               -337645.962002
# texture_mean                73516.970000
# perimeter_mean            -129943.280000
# area_mean                    5953.500000
# smoothness_mean             17310.847850
# compactness_mean            59855.308650
# concavity_mean              85760.881167
# concave points_mean         38221.893065
# symmetry_mean               21440.675500
# fractal_dimension_mean       6762.901600
# radius_se                   -7787.969000
# texture_se                 -55990.659100
# perimeter_se               -85818.105399
# area_se                     20372.902000
# smoothness_se                1888.463091
# compactness_se              10600.455406
# concavity_se                17315.278430
# concave points_se            3906.365299
# symmetry_se                  7880.511436
# fractal_dimension_se          973.299089
# radius_worst              -340075.340002
# texture_worst               29966.870000
# perimeter_worst            103580.120000
# area_worst                   4501.300000
# smoothness_worst            26177.018470
# compactness_worst          159882.480258
# concavity_worst            214800.191687
# concave points_worst        60607.961464
# symmetry_worst              67754.056100
# fractal_dimension_worst     19689.578030
# bias                       -38963.000000
# dtype: float64
# Misclassified:	22	Count:	81915
# radius_mean               -337634.202002
# texture_mean                73546.500000
# perimeter_mean            -129769.530000
# area_mean                    7067.700000
# smoothness_mean             17312.018010
# compactness_mean            59858.414910
# concavity_mean              85765.162887
# concave points_mean         38223.994695
# symmetry_mean               21442.327600
# fractal_dimension_mean       6763.457250
# radius_se                   -7786.991800
# texture_se                 -55991.369600
# perimeter_se               -85815.768399
# area_se                     20443.352000
# smoothness_se                1888.598780
# compactness_se              10600.988566
# concavity_se                17316.203580
# concave points_se            3906.634598
# symmetry_se                  7880.969839
# fractal_dimension_se          973.380073
# radius_worst              -340054.970002
# texture_worst               30005.590000
# perimeter_worst            103803.550000
# area_worst                   6134.300000
# smoothness_worst            26178.752270
# compactness_worst          159889.909058
# concavity_worst            214810.280607
# concave points_worst        60611.377754
# symmetry_worst              67758.380400
# fractal_dimension_worst     19690.812830
# bias                       -38962.000000
# dtype: float64
# Misclassified:	25	Count:	81920
# radius_mean               -337681.892002
# texture_mean                73516.900000
# perimeter_mean            -129992.840000
# area_mean                    6078.600000
# smoothness_mean             17312.547190
# compactness_mean            59860.473110
# concavity_mean              85768.689777
# concave points_mean         38225.685175
# symmetry_mean               21442.884500
# fractal_dimension_mean       6763.589070
# radius_se                   -7788.317600
# texture_se                 -55996.425500
# perimeter_se               -85826.225399
# area_se                     20360.432000
# smoothness_se                1888.747135
# compactness_se              10601.288926
# concavity_se                17317.016110
# concave points_se            3906.867939
# symmetry_se                  7881.295933
# fractal_dimension_se          973.410885
# radius_worst              -340109.540002
# texture_worst               29960.400000
# perimeter_worst            103529.370000
# area_worst                   4426.200000
# smoothness_worst            26179.595910
# compactness_worst          159894.722958
# concavity_worst            214817.641317
# concave points_worst        60613.927494
# symmetry_worst              67760.788700
# fractal_dimension_worst     19691.367720
# bias                       -38966.000000
# dtype: float64
# Misclassified:	22	Count:	81925
# radius_mean               -337676.562002
# texture_mean                73538.990000
# perimeter_mean            -129858.000000
# area_mean                    7331.400000
# smoothness_mean             17313.618390
# compactness_mean            59863.489890
# concavity_mean              85773.117167
# concave points_mean         38227.833385
# symmetry_mean               21444.387700
# fractal_dimension_mean       6764.068970
# radius_se                   -7787.861600
# texture_se                 -55997.538400
# perimeter_se               -85825.389399
# area_se                     20407.842000
# smoothness_se                1888.902229
# compactness_se              10601.812956
# concavity_se                17318.007330
# concave points_se            3907.150064
# symmetry_se                  7881.752596
# fractal_dimension_se          973.481079
# radius_worst              -340098.710002
# texture_worst               29991.730000
# perimeter_worst            103697.960000
# area_worst                   5965.400000
# smoothness_worst            26181.185130
# compactness_worst          159902.065058
# concavity_worst            214827.744737
# concave points_worst        60617.374274
# symmetry_worst              67764.987200
# fractal_dimension_worst     19692.510710
# bias                       -38966.000000
# dtype: float64
# Misclassified:	21	Count:	81930
# radius_mean               -337672.822002
# texture_mean                73590.050000
# perimeter_mean            -129731.170000
# area_mean                    6796.900000
# smoothness_mean             17315.037410
# compactness_mean            59867.011010
# concavity_mean              85777.701597
# concave points_mean         38229.983535
# symmetry_mean               21446.361100
# fractal_dimension_mean       6764.758860
# radius_se                   -7787.097700
# texture_se                 -55999.112300
# perimeter_se               -85824.417399
# area_se                     20416.662000
# smoothness_se                1889.034191
# compactness_se              10602.339286
# concavity_se                17318.885290
# concave points_se            3907.393895
# symmetry_se                  7882.243788
# fractal_dimension_se          973.549413
# radius_worst              -340079.460002
# texture_worst               30067.590000
# perimeter_worst            103923.380000
# area_worst                   6336.500000
# smoothness_worst            26183.394100
# compactness_worst          159911.289358
# concavity_worst            214839.470657
# concave points_worst        60621.121254
# symmetry_worst              67770.095200
# fractal_dimension_worst     19694.038830
# bias                       -38964.000000
# dtype: float64
# Misclassified:	21	Count:	81935
# radius_mean               -337711.782002
# texture_mean                73568.280000
# perimeter_mean            -129897.670000
# area_mean                    5890.500000
# smoothness_mean             17315.682240
# compactness_mean            59869.177630
# concavity_mean              85781.117817
# concave points_mean         38231.643825
# symmetry_mean               21447.058700
# fractal_dimension_mean       6764.955930
# radius_se                   -7786.734000
# texture_se                 -56002.148300
# perimeter_se               -85828.547399
# area_se                     20460.962000
# smoothness_se                1889.175392
# compactness_se              10602.740366
# concavity_se                17319.716690
# concave points_se            3907.636536
# symmetry_se                  7882.624542
# fractal_dimension_se          973.608486
# radius_worst              -340125.290002
# texture_worst               30015.260000
# perimeter_worst            103691.930000
# area_worst                   4597.600000
# smoothness_worst            26184.343100
# compactness_worst          159915.751858
# concavity_worst            214846.188267
# concave points_worst        60623.482424
# symmetry_worst              67772.392700
# fractal_dimension_worst     19694.589550
# bias                       -38967.000000
# dtype: float64
# Misclassified:	24	Count:	81940
# radius_mean               -337706.772002
# texture_mean                73596.120000
# perimeter_mean            -129766.400000
# area_mean                    7136.500000
# smoothness_mean             17316.732480
# compactness_mean            59872.114070
# concavity_mean              85785.456157
# concave points_mean         38233.739455
# symmetry_mean               21448.504400
# fractal_dimension_mean       6765.424900
# radius_se                   -7786.416800
# texture_se                 -56003.583300
# perimeter_se               -85829.168399
# area_se                     20497.712000
# smoothness_se                1889.329737
# compactness_se              10603.227216
# concavity_se                17320.661110
# concave points_se            3907.905047
# symmetry_se                  7883.076815
# fractal_dimension_se          973.675090
# radius_worst              -340115.460002
# texture_worst               30047.660000
# perimeter_worst            103850.720000
# area_worst                   6073.400000
# smoothness_worst            26185.907720
# compactness_worst          159922.794458
# concavity_worst            214855.917277
# concave points_worst        60626.784464
# symmetry_worst              67776.471800
# fractal_dimension_worst     19695.696140
# bias                       -38967.000000
# dtype: float64
# Misclassified:	26	Count:	81945
# radius_mean               -337735.582002
# texture_mean                73589.660000
# perimeter_mean            -129868.230000
# area_mean                    6485.900000
# smoothness_mean             17317.488420
# compactness_mean            59874.431750
# concavity_mean              85788.995177
# concave points_mean         38235.464245
# symmetry_mean               21449.418900
# fractal_dimension_mean       6765.708600
# radius_se                   -7786.886900
# texture_se                 -56007.346600
# perimeter_se               -85835.907399
# area_se                     20465.022000
# smoothness_se                1889.466197
# compactness_se              10603.570156
# concavity_se                17321.444290
# concave points_se            3908.136932
# symmetry_se                  7883.426299
# fractal_dimension_se          973.721774
# radius_worst              -340145.020002
# texture_worst               30033.610000
# perimeter_worst            103734.780000
# area_worst                   5200.700000
# smoothness_worst            26187.075040
# compactness_worst          159928.219958
# concavity_worst            214863.798987
# concave points_worst        60629.477814
# symmetry_worst              67779.404400
# fractal_dimension_worst     19696.467240
# bias                       -38969.000000
# dtype: float64
# Misclassified:	18	Count:	81950
# radius_mean               -337742.702002
# texture_mean                73596.050000
# perimeter_mean            -129815.960000
# area_mean                    7261.600000
# smoothness_mean             17318.431820
# compactness_mean            59877.278530
# concavity_mean              85793.264767
# concave points_mean         38237.531565
# symmetry_mean               21450.713400
# fractal_dimension_mean       6766.112370
# radius_se                   -7786.765400
# texture_se                 -56009.349700
# perimeter_se               -85837.288399
# area_se                     20485.242000
# smoothness_se                1889.613781
# compactness_se              10604.060736
# concavity_se                17322.398790
# concave points_se            3908.407687
# symmetry_se                  7883.861312
# fractal_dimension_se          973.786886
# radius_worst              -340149.660002
# texture_worst               30041.190000
# perimeter_worst            103799.970000
# area_worst                   5998.300000
# smoothness_worst            26188.485160
# compactness_worst          159935.037158
# concavity_worst            214873.366907
# concave points_worst        60632.750494
# symmetry_worst              67783.204400
# fractal_dimension_worst     19697.485830
# bias                       -38970.000000
# dtype: float64
# Misclassified:	21	Count:	81955
# radius_mean               -337758.592002
# texture_mean                73604.510000
# perimeter_mean            -129824.860000
# area_mean                    7128.100000
# smoothness_mean             17319.378610
# compactness_mean            59880.060910
# concavity_mean              85797.407917
# concave points_mean         38239.513505
# symmetry_mean               21452.025800
# fractal_dimension_mean       6766.520510
# radius_se                   -7787.302500
# texture_se                 -56012.176700
# perimeter_se               -85841.636399
# area_se                     20438.702000
# smoothness_se                1889.759965
# compactness_se              10604.476626
# concavity_se                17323.280480
# concave points_se            3908.659905
# symmetry_se                  7884.272455
# fractal_dimension_se          973.833452
# radius_worst              -340160.300002
# texture_worst               30063.610000
# perimeter_worst            103823.860000
# area_worst                   6118.400000
# smoothness_worst            26189.958200
# compactness_worst          159942.231958
# concavity_worst            214883.208327
# concave points_worst        60636.048374
# symmetry_worst              67787.222800
# fractal_dimension_worst     19698.555060
# bias                       -38971.000000
# dtype: float64
# Misclassified:	23	Count:	81960
# radius_mean               -337754.852002
# texture_mean                73655.570000
# perimeter_mean            -129698.030000
# area_mean                    6593.600000
# smoothness_mean             17320.797630
# compactness_mean            59883.582030
# concavity_mean              85801.992347
# concave points_mean         38241.663655
# symmetry_mean               21453.999200
# fractal_dimension_mean       6767.210400
# radius_se                   -7786.538600
# texture_se                 -56013.750600
# perimeter_se               -85840.664399
# area_se                     20447.522000
# smoothness_se                1889.891927
# compactness_se              10605.002956
# concavity_se                17324.158440
# concave points_se            3908.903736
# symmetry_se                  7884.763647
# fractal_dimension_se          973.901786
# radius_worst              -340141.050002
# texture_worst               30139.470000
# perimeter_worst            104049.280000
# area_worst                   6489.500000
# smoothness_worst            26192.167170
# compactness_worst          159951.456258
# concavity_worst            214894.934247
# concave points_worst        60639.795354
# symmetry_worst              67792.330800
# fractal_dimension_worst     19700.083180
# bias                       -38969.000000
# dtype: float64
# Misclassified:	26	Count:	81965
# radius_mean               -337793.242002
# texture_mean                73632.900000
# perimeter_mean            -129863.730000
# area_mean                    6569.700000
# smoothness_mean             17321.232980
# compactness_mean            59885.410030
# concavity_mean              85805.175447
# concave points_mean         38243.242215
# symmetry_mean               21454.331800
# fractal_dimension_mean       6767.282080
# radius_se                   -7786.921500
# texture_se                 -56017.403000
# perimeter_se               -85848.651399
# area_se                     20459.352000
# smoothness_se                1890.040702
# compactness_se              10605.356236
# concavity_se                17324.992670
# concave points_se            3909.151581
# symmetry_se                  7885.072502
# fractal_dimension_se          973.956760
# radius_worst              -340194.070002
# texture_worst               30078.130000
# perimeter_worst            103778.470000
# area_worst                   5086.900000
# smoothness_worst            26192.809670
# compactness_worst          159954.756558
# concavity_worst            214900.600447
# concave points_worst        60641.910264
# symmetry_worst              67793.817200
# fractal_dimension_worst     19700.407890
# bias                       -38973.000000
# dtype: float64
# Misclassified:	18	Count:	81970
# radius_mean               -337801.362002
# texture_mean                73631.070000
# perimeter_mean            -129818.260000
# area_mean                    7249.400000
# smoothness_mean             17322.203770
# compactness_mean            59888.256710
# concavity_mean              85809.468937
# concave points_mean         38245.330575
# symmetry_mean               21455.643500
# fractal_dimension_mean       6767.693310
# radius_se                   -7786.682800
# texture_se                 -56020.031800
# perimeter_se               -85849.709399
# area_se                     20492.622000
# smoothness_se                1890.187052
# compactness_se              10605.829086
# concavity_se                17325.936490
# concave points_se            3909.417406
# symmetry_se                  7885.508615
# fractal_dimension_se          974.021456
# radius_worst              -340197.710002
# texture_worst               30074.300000
# perimeter_worst            103845.160000
# area_worst                   6005.300000
# smoothness_worst            26194.231390
# compactness_worst          159961.465358
# concavity_worst            214910.165167
# concave points_worst        60645.162144
# symmetry_worst              67797.633400
# fractal_dimension_worst     19701.432290
# bias                       -38974.000000
# dtype: float64
# Misclassified:	21	Count:	81975
# radius_mean               -337823.342002
# texture_mean                73629.950000
# perimeter_mean            -129877.740000
# area_mean                    6496.800000
# smoothness_mean             17323.085330
# compactness_mean            59890.677400
# concavity_mean              85812.876527
# concave points_mean         38247.031725
# symmetry_mean               21456.716900
# fractal_dimension_mean       6768.049290
# radius_se                   -7786.573400
# texture_se                 -56023.809600
# perimeter_se               -85854.359399
# area_se                     20485.622000
# smoothness_se                1890.306161
# compactness_se              10606.177296
# concavity_se                17326.644520
# concave points_se            3909.637102
# symmetry_se                  7885.863059
# fractal_dimension_se          974.078146
# radius_worst              -340218.470002
# texture_worst               30058.770000
# perimeter_worst            103784.060000
# area_worst                   5153.000000
# smoothness_worst            26195.571740
# compactness_worst          159966.896658
# concavity_worst            214917.850377
# concave points_worst        60647.824104
# symmetry_worst              67800.667900
# fractal_dimension_worst     19702.279030
# bias                       -38975.000000
# dtype: float64
# Misclassified:	18	Count:	81980
# radius_mean               -337831.462002
# texture_mean                73628.120000
# perimeter_mean            -129832.270000
# area_mean                    7176.500000
# smoothness_mean             17324.056120
# compactness_mean            59893.524080
# concavity_mean              85817.170017
# concave points_mean         38249.120085
# symmetry_mean               21458.028600
# fractal_dimension_mean       6768.460520
# radius_se                   -7786.334700
# texture_se                 -56026.438400
# perimeter_se               -85855.417399
# area_se                     20518.892000
# smoothness_se                1890.452511
# compactness_se              10606.650146
# concavity_se                17327.588340
# concave points_se            3909.902927
# symmetry_se                  7886.299172
# fractal_dimension_se          974.142842
# radius_worst              -340222.110002
# texture_worst               30054.940000
# perimeter_worst            103850.750000
# area_worst                   6071.400000
# smoothness_worst            26196.993460
# compactness_worst          159973.605458
# concavity_worst            214927.415097
# concave points_worst        60651.075984
# symmetry_worst              67804.484100
# fractal_dimension_worst     19703.303430
# bias                       -38976.000000
# dtype: float64
# Misclassified:	23	Count:	81985
# radius_mean               -337840.522002
# texture_mean                73641.920000
# perimeter_mean            -129798.820000
# area_mean                    6941.000000
# smoothness_mean             17325.128530
# compactness_mean            59896.409470
# concavity_mean              85821.181737
# concave points_mean         38251.078385
# symmetry_mean               21459.499900
# fractal_dimension_mean       6768.940940
# radius_se                   -7786.292300
# texture_se                 -56029.279900
# perimeter_se               -85857.676399
# area_se                     20498.042000
# smoothness_se                1890.581344
# compactness_se              10607.071306
# concavity_se                17328.394880
# concave points_se            3910.142956
# symmetry_se                  7886.715275
# fractal_dimension_se          974.199414
# radius_worst              -340223.950002
# texture_worst               30075.880000
# perimeter_worst            103929.480000
# area_worst                   6211.900000
# smoothness_worst            26198.639530
# compactness_worst          159980.806058
# concavity_worst            214937.060017
# concave points_worst        60654.342474
# symmetry_worst              67808.604400
# fractal_dimension_worst     19704.448300
# bias                       -38976.000000
# dtype: float64
# Misclassified:	26	Count:	81990
# radius_mean               -337888.212002
# texture_mean                73612.320000
# perimeter_mean            -130022.130000
# area_mean                    5951.900000
# smoothness_mean             17325.657710
# compactness_mean            59898.467670
# concavity_mean              85824.708627
# concave points_mean         38252.768865
# symmetry_mean               21460.056800
# fractal_dimension_mean       6769.072760
# radius_se                   -7787.618100
# texture_se                 -56034.335800
# perimeter_se               -85868.133399
# area_se                     20415.122000
# smoothness_se                1890.729699
# compactness_se              10607.371666
# concavity_se                17329.207410
# concave points_se            3910.376297
# symmetry_se                  7887.041369
# fractal_dimension_se          974.230226
# radius_worst              -340278.520002
# texture_worst               30030.690000
# perimeter_worst            103655.300000
# area_worst                   4503.800000
# smoothness_worst            26199.483170
# compactness_worst          159985.619958
# concavity_worst            214944.420727
# concave points_worst        60656.892214
# symmetry_worst              67811.012700
# fractal_dimension_worst     19705.003190
# bias                       -38980.000000
# dtype: float64
# Misclassified:	22	Count:	81995
# radius_mean               -337876.452002
# texture_mean                73641.850000
# perimeter_mean            -129848.380000
# area_mean                    7066.100000
# smoothness_mean             17326.827870
# compactness_mean            59901.573930
# concavity_mean              85828.990347
# concave points_mean         38254.870495
# symmetry_mean               21461.708900
# fractal_dimension_mean       6769.628410
# radius_se                   -7786.640900
# texture_se                 -56035.046300
# perimeter_se               -85865.796399
# area_se                     20485.572000
# smoothness_se                1890.865388
# compactness_se              10607.904826
# concavity_se                17330.132560
# concave points_se            3910.645596
# symmetry_se                  7887.499772
# fractal_dimension_se          974.311210
# radius_worst              -340258.150002
# texture_worst               30069.410000
# perimeter_worst            103878.730000
# area_worst                   6136.800000
# smoothness_worst            26201.216970
# compactness_worst          159993.048758
# concavity_worst            214954.509647
# concave points_worst        60660.308504
# symmetry_worst              67815.337000
# fractal_dimension_worst     19706.237990
# bias                       -38979.000000
# dtype: float64
# Misclassified:	25	Count:	82000
# radius_mean               -337924.142002
# texture_mean                73612.250000
# perimeter_mean            -130071.690000
# area_mean                    6077.000000
# smoothness_mean             17327.357050
# compactness_mean            59903.632130
# concavity_mean              85832.517237
# concave points_mean         38256.560975
# symmetry_mean               21462.265800
# fractal_dimension_mean       6769.760230
# radius_se                   -7787.966700
# texture_se                 -56040.102200
# perimeter_se               -85876.253399
# area_se                     20402.652000
# smoothness_se                1891.013743
# compactness_se              10608.205186
# concavity_se                17330.945090
# concave points_se            3910.878937
# symmetry_se                  7887.825866
# fractal_dimension_se          974.342022
# radius_worst              -340312.720002
# texture_worst               30024.220000
# perimeter_worst            103604.550000
# area_worst                   4428.700000
# smoothness_worst            26202.060610
# compactness_worst          159997.862658
# concavity_worst            214961.870357
# concave points_worst        60662.858244
# symmetry_worst              67817.745300
# fractal_dimension_worst     19706.792880
# bias                       -38983.000000
# dtype: float64
# Misclassified:	22	Count:	82005
# radius_mean               -337918.812002
# texture_mean                73634.340000
# perimeter_mean            -129936.850000
# area_mean                    7329.800000
# smoothness_mean             17328.428250
# compactness_mean            59906.648910
# concavity_mean              85836.944627
# concave points_mean         38258.709185
# symmetry_mean               21463.769000
# fractal_dimension_mean       6770.240130
# radius_se                   -7787.510700
# texture_se                 -56041.215100
# perimeter_se               -85875.417399
# area_se                     20450.062000
# smoothness_se                1891.168837
# compactness_se              10608.729216
# concavity_se                17331.936310
# concave points_se            3911.161062
# symmetry_se                  7888.282529
# fractal_dimension_se          974.412216
# radius_worst              -340301.890002
# texture_worst               30055.550000
# perimeter_worst            103773.140000
# area_worst                   5967.900000
# smoothness_worst            26203.649830
# compactness_worst          160005.204758
# concavity_worst            214971.973777
# concave points_worst        60666.305024
# symmetry_worst              67821.943800
# fractal_dimension_worst     19707.935870
# bias                       -38983.000000
# dtype: float64
# Misclassified:	21	Count:	82010
# radius_mean               -337915.072002
# texture_mean                73685.400000
# perimeter_mean            -129810.020000
# area_mean                    6795.300000
# smoothness_mean             17329.847270
# compactness_mean            59910.170030
# concavity_mean              85841.529057
# concave points_mean         38260.859335
# symmetry_mean               21465.742400
# fractal_dimension_mean       6770.930020
# radius_se                   -7786.746800
# texture_se                 -56042.789000
# perimeter_se               -85874.445399
# area_se                     20458.882000
# smoothness_se                1891.300799
# compactness_se              10609.255546
# concavity_se                17332.814270
# concave points_se            3911.404893
# symmetry_se                  7888.773721
# fractal_dimension_se          974.480550
# radius_worst              -340282.640002
# texture_worst               30131.410000
# perimeter_worst            103998.560000
# area_worst                   6339.000000
# smoothness_worst            26205.858800
# compactness_worst          160014.429058
# concavity_worst            214983.699697
# concave points_worst        60670.052004
# symmetry_worst              67827.051800
# fractal_dimension_worst     19709.463990
# bias                       -38981.000000
# dtype: float64
# Misclassified:	21	Count:	82015
# radius_mean               -337954.032002
# texture_mean                73663.630000
# perimeter_mean            -129976.520000
# area_mean                    5888.900000
# smoothness_mean             17330.492100
# compactness_mean            59912.336650
# concavity_mean              85844.945277
# concave points_mean         38262.519625
# symmetry_mean               21466.440000
# fractal_dimension_mean       6771.127090
# radius_se                   -7786.383100
# texture_se                 -56045.825000
# perimeter_se               -85878.575399
# area_se                     20503.182000
# smoothness_se                1891.442000
# compactness_se              10609.656626
# concavity_se                17333.645670
# concave points_se            3911.647534
# symmetry_se                  7889.154475
# fractal_dimension_se          974.539623
# radius_worst              -340328.470002
# texture_worst               30079.080000
# perimeter_worst            103767.110000
# area_worst                   4600.100000
# smoothness_worst            26206.807800
# compactness_worst          160018.891558
# concavity_worst            214990.417307
# concave points_worst        60672.413174
# symmetry_worst              67829.349300
# fractal_dimension_worst     19710.014710
# bias                       -38984.000000
# dtype: float64
# Misclassified:	24	Count:	82020
# radius_mean               -337949.022002
# texture_mean                73691.470000
# perimeter_mean            -129845.250000
# area_mean                    7134.900000
# smoothness_mean             17331.542340
# compactness_mean            59915.273090
# concavity_mean              85849.283617
# concave points_mean         38264.615255
# symmetry_mean               21467.885700
# fractal_dimension_mean       6771.596060
# radius_se                   -7786.065900
# texture_se                 -56047.260000
# perimeter_se               -85879.196399
# area_se                     20539.932000
# smoothness_se                1891.596345
# compactness_se              10610.143476
# concavity_se                17334.590090
# concave points_se            3911.916045
# symmetry_se                  7889.606748
# fractal_dimension_se          974.606227
# radius_worst              -340318.640002
# texture_worst               30111.480000
# perimeter_worst            103925.900000
# area_worst                   6075.900000
# smoothness_worst            26208.372420
# compactness_worst          160025.934158
# concavity_worst            215000.146317
# concave points_worst        60675.715214
# symmetry_worst              67833.428400
# fractal_dimension_worst     19711.121300
# bias                       -38984.000000
# dtype: float64
# Misclassified:	26	Count:	82025
# radius_mean               -337977.832002
# texture_mean                73685.010000
# perimeter_mean            -129947.080000
# area_mean                    6484.300000
# smoothness_mean             17332.298280
# compactness_mean            59917.590770
# concavity_mean              85852.822637
# concave points_mean         38266.340045
# symmetry_mean               21468.800200
# fractal_dimension_mean       6771.879760
# radius_se                   -7786.536000
# texture_se                 -56051.023300
# perimeter_se               -85885.935399
# area_se                     20507.242000
# smoothness_se                1891.732805
# compactness_se              10610.486416
# concavity_se                17335.373270
# concave points_se            3912.147930
# symmetry_se                  7889.956232
# fractal_dimension_se          974.652911
# radius_worst              -340348.200002
# texture_worst               30097.430000
# perimeter_worst            103809.960000
# area_worst                   5203.200000
# smoothness_worst            26209.539740
# compactness_worst          160031.359658
# concavity_worst            215008.028027
# concave points_worst        60678.408564
# symmetry_worst              67836.361000
# fractal_dimension_worst     19711.892400
# bias                       -38986.000000
# dtype: float64
# Misclassified:	18	Count:	82030
# radius_mean               -337984.952002
# texture_mean                73691.400000
# perimeter_mean            -129894.810000
# area_mean                    7260.000000
# smoothness_mean             17333.241680
# compactness_mean            59920.437550
# concavity_mean              85857.092227
# concave points_mean         38268.407365
# symmetry_mean               21470.094700
# fractal_dimension_mean       6772.283530
# radius_se                   -7786.414500
# texture_se                 -56053.026400
# perimeter_se               -85887.316399
# area_se                     20527.462000
# smoothness_se                1891.880389
# compactness_se              10610.976996
# concavity_se                17336.327770
# concave points_se            3912.418685
# symmetry_se                  7890.391245
# fractal_dimension_se          974.718023
# radius_worst              -340352.840002
# texture_worst               30105.010000
# perimeter_worst            103875.150000
# area_worst                   6000.800000
# smoothness_worst            26210.949860
# compactness_worst          160038.176858
# concavity_worst            215017.595947
# concave points_worst        60681.681244
# symmetry_worst              67840.161000
# fractal_dimension_worst     19712.910990
# bias                       -38987.000000
# dtype: float64
# Misclassified:	21	Count:	82035
# radius_mean               -338000.842002
# texture_mean                73699.860000
# perimeter_mean            -129903.710000
# area_mean                    7126.500000
# smoothness_mean             17334.188470
# compactness_mean            59923.219930
# concavity_mean              85861.235377
# concave points_mean         38270.389305
# symmetry_mean               21471.407100
# fractal_dimension_mean       6772.691670
# radius_se                   -7786.951600
# texture_se                 -56055.853400
# perimeter_se               -85891.664399
# area_se                     20480.922000
# smoothness_se                1892.026573
# compactness_se              10611.392886
# concavity_se                17337.209460
# concave points_se            3912.670903
# symmetry_se                  7890.802388
# fractal_dimension_se          974.764589
# radius_worst              -340363.480002
# texture_worst               30127.430000
# perimeter_worst            103899.040000
# area_worst                   6120.900000
# smoothness_worst            26212.422900
# compactness_worst          160045.371658
# concavity_worst            215027.437367
# concave points_worst        60684.979124
# symmetry_worst              67844.179400
# ...
# symmetry_worst              68211.895200
# fractal_dimension_worst     19814.029420
# bias                       -39096.000000
# dtype: float64
# Misclassified:	24	Count:	82555
# radius_mean               -339591.522003
# texture_mean                74202.380000
# perimeter_mean            -130515.550000
# area_mean                    5040.100000
# smoothness_mean             17430.776560
# compactness_mean            60204.313560
# concavity_mean              86276.788447
# concave points_mean         38471.285035
# symmetry_mean               21597.637300
# fractal_dimension_mean       6812.876170
# radius_se                   -7787.388200
# texture_se                 -56352.100300
# perimeter_se               -86230.512399
# area_se                     20455.362000
# smoothness_se                1906.605628
# compactness_se              10655.890796
# concavity_se                17427.096520
# concave points_se            3938.490649
# symmetry_se                  7933.017975
# fractal_dimension_se          980.670888
# radius_worst              -341685.910002
# texture_worst               30445.390000
# perimeter_worst            104407.470000
# area_worst                   5305.600000
# smoothness_worst            26359.103600
# compactness_worst          160720.554868
# concavity_worst            215970.528177
# concave points_worst        61003.853674
# symmetry_worst              68214.844900
# fractal_dimension_worst     19814.685050
# bias                       -39099.000000
# dtype: float64
# Misclassified:	24	Count:	82560
# radius_mean               -339570.612003
# texture_mean                74247.650000
# perimeter_mean            -130286.020000
# area_mean                    6112.900000
# smoothness_mean             17432.063880
# compactness_mean            60207.520970
# concavity_mean              86281.105787
# concave points_mean         38473.384945
# symmetry_mean               21599.522800
# fractal_dimension_mean       6813.501930
# radius_se                   -7786.825700
# texture_se                 -56353.502500
# perimeter_se               -86228.445399
# area_se                     20462.072000
# smoothness_se                1906.699970
# compactness_se              10656.251716
# concavity_se                17427.776270
# concave points_se            3938.697707
# symmetry_se                  7933.517307
# fractal_dimension_se          980.703754
# radius_worst              -341656.420002
# texture_worst               30510.160000
# perimeter_worst            104696.660000
# area_worst                   6833.400000
# smoothness_worst            26361.029710
# compactness_worst          160729.125278
# concavity_worst            215981.550067
# concave points_worst        61007.436674
# symmetry_worst              68220.110900
# fractal_dimension_worst     19816.062670
# bias                       -39097.000000
# dtype: float64
# Misclassified:	21	Count:	82565
# radius_mean               -339592.362003
# texture_mean                74272.800000
# perimeter_mean            -130338.870000
# area_mean                    5184.300000
# smoothness_mean             17433.008150
# compactness_mean            60210.132290
# concavity_mean              86284.987317
# concave points_mean         38475.174405
# symmetry_mean               21600.519700
# fractal_dimension_mean       6813.895080
# radius_se                   -7786.638000
# texture_se                 -56354.648800
# perimeter_se               -86233.865399
# area_se                     20463.392000
# smoothness_se                1906.812154
# compactness_se              10656.546266
# concavity_se                17428.469490
# concave points_se            3938.880474
# symmetry_se                  7933.911270
# fractal_dimension_se          980.731083
# radius_worst              -341677.700002
# texture_worst               30534.690000
# perimeter_worst            104625.470000
# area_worst                   5636.100000
# smoothness_worst            26362.472220
# compactness_worst          160735.687788
# concavity_worst            215990.738357
# concave points_worst        61010.179564
# symmetry_worst              68223.282500
# fractal_dimension_worst     19817.016040
# bias                       -39098.000000
# dtype: float64
# Misclassified:	21	Count:	82570
# radius_mean               -339597.812003
# texture_mean                74289.100000
# perimeter_mean            -130298.040000
# area_mean                    5062.300000
# smoothness_mean             17433.963100
# compactness_mean            60212.577660
# concavity_mean              86288.532607
# concave points_mean         38476.870125
# symmetry_mean               21601.931600
# fractal_dimension_mean       6814.305220
# radius_se                   -7786.760900
# texture_se                 -56360.210700
# perimeter_se               -86233.414399
# area_se                     20409.272000
# smoothness_se                1906.881513
# compactness_se              10656.649446
# concavity_se                17428.904540
# concave points_se            3939.025575
# symmetry_se                  7934.331724
# fractal_dimension_se          980.706114
# radius_worst              -341683.370002
# texture_worst               30544.500000
# perimeter_worst            104671.450000
# area_worst                   5227.200000
# smoothness_worst            26363.879690
# compactness_worst          160742.578708
# concavity_worst            215999.869317
# concave points_worst        61013.024414
# symmetry_worst              68227.840800
# fractal_dimension_worst     19817.990220
# bias                       -39098.000000
# dtype: float64
# Misclassified:	18	Count:	82575
# radius_mean               -339587.332003
# texture_mean                74360.640000
# perimeter_mean            -130142.330000
# area_mean                    5084.800000
# smoothness_mean             17435.208050
# compactness_mean            60215.601800
# concavity_mean              86292.657047
# concave points_mean         38478.774345
# symmetry_mean               21603.653600
# fractal_dimension_mean       6814.923810
# radius_se                   -7786.825600
# texture_se                 -56360.784500
# perimeter_se               -86236.442399
# area_se                     20352.682000
# smoothness_se                1906.978268
# compactness_se              10656.918426
# concavity_se                17429.516350
# concave points_se            3939.196209
# symmetry_se                  7934.816836
# fractal_dimension_se          980.720089
# radius_worst              -341664.210002
# texture_worst               30644.670000
# perimeter_worst            104878.880000
# area_worst                   5641.500000
# smoothness_worst            26365.791920
# compactness_worst          160750.917818
# concavity_worst            216010.713697
# concave points_worst        61016.291544
# symmetry_worst              68232.911100
# fractal_dimension_worst     19819.344400
# bias                       -39096.000000
# dtype: float64
# Misclassified:	21	Count:	82580
# radius_mean               -339587.232003
# texture_mean                74323.320000
# perimeter_mean            -130055.340000
# area_mean                    6293.500000
# smoothness_mean             17436.136090
# compactness_mean            60218.145340
# concavity_mean              86296.487217
# concave points_mean         38480.704925
# symmetry_mean               21604.972000
# fractal_dimension_mean       6815.270960
# radius_se                   -7787.302200
# texture_se                 -56368.768000
# perimeter_se               -86239.939399
# area_se                     20308.232000
# smoothness_se                1907.041153
# compactness_se              10657.064916
# concavity_se                17430.000500
# concave points_se            3939.346623
# symmetry_se                  7935.171958
# fractal_dimension_se          980.712042
# radius_worst              -341663.750002
# texture_worst               30589.920000
# perimeter_worst            104974.560000
# area_worst                   6851.000000
# smoothness_worst            26367.128600
# compactness_worst          160757.536728
# concavity_worst            216020.041787
# concave points_worst        61019.339394
# symmetry_worst              68236.774100
# fractal_dimension_worst     19820.241760
# bias                       -39097.000000
# dtype: float64
# Misclassified:	19	Count:	82585
# radius_mean               -339618.372003
# texture_mean                74286.190000
# perimeter_mean            -130180.620000
# area_mean                    5130.000000
# smoothness_mean             17436.902290
# compactness_mean            60220.349370
# concavity_mean              86299.870417
# concave points_mean         38482.341975
# symmetry_mean               21606.035200
# fractal_dimension_mean       6815.536080
# radius_se                   -7788.937600
# texture_se                 -56377.768700
# perimeter_se               -86248.965399
# area_se                     20134.192000
# smoothness_se                1907.097322
# compactness_se              10657.115896
# concavity_se                17430.398480
# concave points_se            3939.468135
# symmetry_se                  7935.532510
# fractal_dimension_se          980.678917
# radius_worst              -341699.060002
# texture_worst               30538.090000
# perimeter_worst            104835.930000
# area_worst                   5165.600000
# smoothness_worst            26368.285450
# compactness_worst          160763.728638
# concavity_worst            216028.654277
# concave points_worst        61022.041594
# symmetry_worst              68240.607600
# fractal_dimension_worst     19821.008130
# bias                       -39099.000000
# dtype: float64
# Misclassified:	18	Count:	82590
# radius_mean               -339597.952003
# texture_mean                74335.310000
# perimeter_mean            -129960.830000
# area_mean                    6176.000000
# smoothness_mean             17438.112310
# compactness_mean            60223.332310
# concavity_mean              86303.998317
# concave points_mean         38484.296725
# symmetry_mean               21607.860900
# fractal_dimension_mean       6816.137060
# radius_se                   -7789.005500
# texture_se                 -56380.621400
# perimeter_se               -86250.106399
# area_se                     20089.192000
# smoothness_se                1907.182335
# compactness_se              10657.368276
# concavity_se                17430.986900
# concave points_se            3939.637842
# symmetry_se                  7936.005162
# fractal_dimension_se          980.689175
# radius_worst              -341669.110002
# texture_worst               30608.660000
# perimeter_worst            105119.120000
# area_worst                   6796.400000
# smoothness_worst            26370.102580
# compactness_worst          160771.951948
# concavity_worst            216039.506257
# concave points_worst        61025.375254
# symmetry_worst              68245.872700
# fractal_dimension_worst     19822.333820
# bias                       -39097.000000
# dtype: float64
# Misclassified:	26	Count:	82595
# radius_mean               -339629.312003
# texture_mean                74304.580000
# perimeter_mean            -130072.280000
# area_mean                    4958.200000
# smoothness_mean             17439.073570
# compactness_mean            60225.980610
# concavity_mean              86308.001977
# concave points_mean         38486.172565
# symmetry_mean               21608.825800
# fractal_dimension_mean       6816.484080
# radius_se                   -7788.692800
# texture_se                 -56386.070700
# perimeter_se               -86255.357399
# area_se                     20106.262000
# smoothness_se                1907.268110
# compactness_se              10657.617566
# concavity_se                17431.602300
# concave points_se            3939.786512
# symmetry_se                  7936.366314
# fractal_dimension_se          980.708510
# radius_worst              -341698.190002
# texture_worst               30552.800000
# perimeter_worst            104997.890000
# area_worst                   5582.900000
# smoothness_worst            26371.524690
# compactness_worst          160778.529758
# concavity_worst            216049.004657
# concave points_worst        61028.121334
# symmetry_worst              68248.804700
# fractal_dimension_worst     19823.236990
# bias                       -39099.000000
# dtype: float64
# Misclassified:	20	Count:	82600
# radius_mean               -339663.192003
# texture_mean                74205.010000
# perimeter_mean            -130202.130000
# area_mean                    5004.000000
# smoothness_mean             17439.715570
# compactness_mean            60228.235950
# concavity_mean              86311.702787
# concave points_mean         38488.030395
# symmetry_mean               21609.431700
# fractal_dimension_mean       6816.626770
# radius_se                   -7789.379200
# texture_se                 -56397.398900
# perimeter_se               -86266.069399
# area_se                     20069.622000
# smoothness_se                1907.324776
# compactness_se              10657.838856
# concavity_se                17432.177310
# concave points_se            3939.927906
# symmetry_se                  7936.635004
# fractal_dimension_se          980.727938
# radius_worst              -341737.050002
# texture_worst               30398.630000
# perimeter_worst            104821.980000
# area_worst                   5267.400000
# smoothness_worst            26372.422610
# compactness_worst          160783.585358
# concavity_worst            216057.193977
# concave points_worst        61030.648654
# symmetry_worst              68250.732100
# fractal_dimension_worst     19823.781090
# bias                       -39103.000000
# dtype: float64
# Misclassified:	18	Count:	82605
# radius_mean               -339642.052003
# texture_mean                74246.280000
# perimeter_mean            -129975.330000
# area_mean                    6093.400000
# smoothness_mean             17440.973210
# compactness_mean            60231.312760
# concavity_mean              86315.933977
# concave points_mean         38490.060665
# symmetry_mean               21611.324900
# fractal_dimension_mean       6817.235210
# radius_se                   -7789.250000
# texture_se                 -56400.346400
# perimeter_se               -86265.165399
# area_se                     20037.932000
# smoothness_se                1907.412592
# compactness_se              10658.124556
# concavity_se                17432.803450
# concave points_se            3940.111864
# symmetry_se                  7937.115266
# fractal_dimension_se          980.741002
# radius_worst              -341706.840002
# texture_worst               30459.260000
# perimeter_worst            105114.970000
# area_worst                   6888.200000
# smoothness_worst            26374.292790
# compactness_worst          160792.027268
# concavity_worst            216068.238367
# concave points_worst        61034.126154
# symmetry_worst              68256.092700
# fractal_dimension_worst     19825.127010
# bias                       -39101.000000
# dtype: float64
# Misclassified:	26	Count:	82610
# radius_mean               -339663.182003
# texture_mean                74253.590000
# perimeter_mean            -130036.210000
# area_mean                    5194.800000
# smoothness_mean             17441.802660
# compactness_mean            60233.569590
# concavity_mean              86319.368977
# concave points_mean         38491.662715
# symmetry_mean               21612.389800
# fractal_dimension_mean       6817.569650
# radius_se                   -7790.795600
# texture_se                 -56405.943400
# perimeter_se               -86276.226399
# area_se                     19873.742000
# smoothness_se                1907.479963
# compactness_se              10658.178186
# concavity_se                17433.216900
# concave points_se            3940.226855
# symmetry_se                  7937.493228
# fractal_dimension_se          980.712297
# radius_worst              -341730.540002
# texture_worst               30467.880000
# perimeter_worst            105039.580000
# area_worst                   5541.200000
# smoothness_worst            26375.574040
# compactness_worst          160798.314078
# concavity_worst            216077.029347
# concave points_worst        61036.740984
# symmetry_worst              68259.876300
# fractal_dimension_worst     19825.980340
# bias                       -39102.000000
# dtype: float64
# Misclassified:	21	Count:	82615
